# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt

df = pd.read_csv('CSVrawdata.csv')
colors_to_filter = ['Blue', 'Red', 'Brown', 'Orange', 'Yellow']
blue_filter = df['Color'] == 'Green'
color_filter = df['Color'].isin(colors_to_filter)
blue = df[blue_filter &  ~m_filter]
mass = blue['Mass']
print(mass)

plt.figure(figsize=(15,8))
plot = plt.hist(mass)


plt.title('Candy frequency')
plt.xlabel('Milligrams')
plt.ylabel('Amount of candies')
plt.show()
# Out:
# 3      1.682
# 4      3.491
# 6      2.907
# 7      2.247
# 12     2.663
#        ...
# 595    2.973
# 597    2.116
# 602    3.938
# 607    2.973
# 615    1.697
# Name: Mass, Length: 130, dtype: float64
